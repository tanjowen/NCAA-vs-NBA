# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt

ncaa_17_18 = pd.read_csv("NCAA data/ncaa data 17-18.csv")
ncaa_16_17 = pd.read_csv("NCAA data/ncaa data 16-17.csv")
ncaa_15_16 = pd.read_csv("NCAA data/ncaa data 15-16.csv")
ncaa_14_15 = pd.read_csv("NCAA data/ncaa data 14-15.csv")
ncaa_13_14 = pd.read_csv("NCAA data/ncaa data 13-14.csv")

# %%
ncaa_13_14_x = ncaa_13_14.drop(ncaa_13_14.index[30:])
ncaa_14_15_x = ncaa_14_15.drop(ncaa_14_15.index[30:])
ncaa_15_16_x = ncaa_15_16.drop(ncaa_15_16.index[30:])
ncaa_16_17_x = ncaa_16_17.drop(ncaa_16_17.index[30:])
ncaa_17_18_x = ncaa_17_18.drop(ncaa_17_18.index[30:])
ncaa_13_14_x.head()
# Out:
#    Rk             School   G   W  L   W-L%    SRS   SOS   Tm.  Opp. ...    FT  \
# 0   1      Wichita State  36  35  1  0.972  16.65  1.74  2706  2141 ...   664
# 1   2            Florida  39  36  3  0.923  20.69  8.54  2727  2253 ...   582
# 2   3  Stephen F. Austin  35  32  3  0.914   4.82 -6.76  2661  2219 ...   569
# 3   4            Arizona  38  33  5  0.868  23.36  9.04  2769  2225 ...   573
# 4   5    San Diego State  36  31  5  0.861  14.95  4.86  2530  2052 ...   598
#
#    FTA    FT%  ORB   TRB  AST  STL  BLK  TOV   PF
# 0  916  0.725  419  1381  491  247  184  374  611
# 1  871  0.668  437  1385  509  274  118  418  611
# 2  800  0.711  451  1186  574  257  104  393  730
# 3  870  0.659  465  1449  574  223  173  387  630
# 4  902  0.663  470  1364  356  274  183  355  600
#
# [5 rows x 28 columns]

# %%
#top 30 teams div 1
ncaa_13_14_two = pd.DataFrame()
ncaa_14_15_two = pd.DataFrame()
ncaa_15_16_two = pd.DataFrame()
ncaa_16_17_two = pd.DataFrame()
ncaa_17_18_two = pd.DataFrame()
#find the amount of 2PA 
ncaa_13_14_2P_2PA = ncaa_13_14_x['FGA'] - ncaa_13_14_x['3PA']
ncaa_14_15_2P_2PA = ncaa_14_15_x['FGA'] - ncaa_14_15_x['3PA']
ncaa_15_16_2P_2PA = ncaa_15_16_x['FGA'] - ncaa_15_16_x['3PA']
ncaa_16_17_2P_2PA = ncaa_16_17_x['FGA'] - ncaa_16_17_x['3PA']
ncaa_17_18_2P_2PA = ncaa_17_18_x['FGA'] - ncaa_17_18_x['3PA']

#find the amount of 2P
ncaa_13_14_2P_ = ncaa_13_14_x['FG'] - ncaa_13_14_x['3P']
ncaa_14_15_2P_ = ncaa_14_15_x['FG'] - ncaa_14_15_x['3P']
ncaa_15_16_2P_ = ncaa_15_16_x['FG'] - ncaa_15_16_x['3P']
ncaa_16_17_2P_ = ncaa_16_17_x['FG'] - ncaa_16_17_x['3P']
ncaa_17_18_2P_ = ncaa_17_18_x['FG'] - ncaa_17_18_x['3P']

#calc the 2P per game
ncaa_13_14_two['2P'] = ncaa_13_14_2P_/ncaa_13_14_x['G']
ncaa_14_15_two['2P'] = ncaa_14_15_2P_/ncaa_14_15_x['G']
ncaa_15_16_two['2P'] = ncaa_15_16_2P_/ncaa_15_16_x['G']
ncaa_16_17_two['2P'] = ncaa_16_17_2P_/ncaa_16_17_x['G']
ncaa_17_18_two['2P'] = ncaa_17_18_2P_/ncaa_17_18_x['G']

#calc the 2PA per game
ncaa_13_14_two['2PA'] = ncaa_13_14_2P_2PA/ncaa_13_14_x['G']
ncaa_14_15_two['2PA'] = ncaa_14_15_2P_2PA/ncaa_14_15_x['G']
ncaa_15_16_two['2PA'] = ncaa_15_16_2P_2PA/ncaa_15_16_x['G']
ncaa_16_17_two['2PA'] = ncaa_16_17_2P_2PA/ncaa_16_17_x['G']
ncaa_17_18_two['2PA'] = ncaa_17_18_2P_2PA/ncaa_17_18_x['G']

#calc the 3P per game
ncaa_13_14_two['3P'] = ncaa_13_14_x['3P']/ncaa_13_14_x['G']
ncaa_14_15_two['3P'] = ncaa_14_15_x['3P']/ncaa_14_15_x['G']
ncaa_15_16_two['3P'] = ncaa_15_16_x['3P']/ncaa_15_16_x['G']
ncaa_16_17_two['3P'] = ncaa_16_17_x['3P']/ncaa_16_17_x['G']
ncaa_17_18_two['3P'] = ncaa_17_18_x['3P']/ncaa_17_18_x['G']

#calc the 3PA per game
ncaa_13_14_two['3PA'] = ncaa_13_14_x['3PA']/ncaa_13_14_x['G']
ncaa_14_15_two['3PA'] = ncaa_14_15_x['3PA']/ncaa_14_15_x['G']
ncaa_15_16_two['3PA'] = ncaa_15_16_x['3PA']/ncaa_15_16_x['G']
ncaa_16_17_two['3PA'] = ncaa_16_17_x['3PA']/ncaa_16_17_x['G']
ncaa_17_18_two['3PA'] = ncaa_17_18_x['3PA']/ncaa_17_18_x['G']

#add year to the dataframe
ncaa_13_14_two['Year'] = '2014'
ncaa_14_15_two['Year'] = '2015'
ncaa_15_16_two['Year'] = '2016'
ncaa_16_17_two['Year'] = '2017'
ncaa_17_18_two['Year'] = '2018'

#groupby year and find avg per game stats of top 30 teams
ncaa_13_14_two = ncaa_13_14_two.groupby(['Year'])
ncaa_13_14_two = (ncaa_13_14_two.sum()/30)
ncaa_14_15_two = ncaa_14_15_two.groupby(['Year'])
ncaa_14_15_two = ncaa_14_15_two.sum()/30
ncaa_15_16_two = ncaa_15_16_two.groupby(['Year'])
ncaa_15_16_two = ncaa_15_16_two.sum()/30
ncaa_16_17_two = ncaa_16_17_two.groupby(['Year'])
ncaa_16_17_two = ncaa_16_17_two.sum()/30
ncaa_17_18_two = ncaa_17_18_two.groupby(['Year'])
ncaa_17_18_two = ncaa_17_18_two.sum()/30

# %%
combined_ncaa_2and3tot = pd.merge(ncaa_13_14_two, ncaa_14_15_two, how='outer', on=['Year', '3P', '3PA', '2P', '2PA'])
combined_ncaa_2and3tot = pd.merge(combined_ncaa_2and3tot, ncaa_15_16_two, how='outer', on=['Year', '3P', '3PA', '2P', '2PA'])
combined_ncaa_2and3tot = pd.merge(combined_ncaa_2and3tot, ncaa_16_17_two, how='outer', on=['Year', '3P', '3PA', '2P', '2PA'])
combined_ncaa_2and3tot = pd.merge(combined_ncaa_2and3tot, ncaa_17_18_two, how='outer', on=['Year', '3P', '3PA', '2P', '2PA'])
combined_ncaa_2and3tot
# Out:
#              2P        2PA        3P        3PA
# Year
# 2014  19.199502  37.289971  6.705064  18.412434
# 2015  18.236922  35.398473  7.036767  19.031358
# 2016  19.692080  37.883634  7.547320  20.363281
# 2017  19.503946  36.514099  8.210101  21.939394
# 2018  19.495131  36.567836  8.256762  21.927788

# %%
#Bot 30 Teams div 1
ncaa_13_14_bot = ncaa_13_14.drop(ncaa_13_14.index[:-30])
ncaa_14_15_bot = ncaa_14_15.drop(ncaa_14_15.index[:-30])
ncaa_15_16_bot = ncaa_15_16.drop(ncaa_15_16.index[:-30])
ncaa_16_17_bot = ncaa_16_17.drop(ncaa_16_17.index[:-30])
ncaa_17_18_bot = ncaa_17_18.drop(ncaa_17_18.index[:-30])

# %%
ncaa_13_14_two_bot = pd.DataFrame()
ncaa_14_15_two_bot = pd.DataFrame()
ncaa_15_16_two_bot = pd.DataFrame()
ncaa_16_17_two_bot = pd.DataFrame()
ncaa_17_18_two_bot = pd.DataFrame()

#find the amount of 2PA 
ncaa_13_14_2P_2PA_bot = ncaa_13_14_bot['FGA'] - ncaa_13_14_bot['3PA']
ncaa_14_15_2P_2PA_bot = ncaa_14_15_bot['FGA'] - ncaa_14_15_bot['3PA']
ncaa_15_16_2P_2PA_bot = ncaa_15_16_bot['FGA'] - ncaa_15_16_bot['3PA']
ncaa_16_17_2P_2PA_bot = ncaa_16_17_bot['FGA'] - ncaa_16_17_bot['3PA']
ncaa_17_18_2P_2PA_bot = ncaa_17_18_bot['FGA'] - ncaa_17_18_bot['3PA']

#find the amount of 2P
ncaa_13_14_2P_bot = ncaa_13_14_bot['FG'] - ncaa_13_14_bot['3P']
ncaa_14_15_2P_bot = ncaa_14_15_bot['FG'] - ncaa_14_15_bot['3P']
ncaa_15_16_2P_bot = ncaa_15_16_bot['FG'] - ncaa_15_16_bot['3P']
ncaa_16_17_2P_bot = ncaa_16_17_bot['FG'] - ncaa_16_17_bot['3P']
ncaa_17_18_2P_bot = ncaa_17_18_bot['FG'] - ncaa_17_18_bot['3P']

#calc the 2P per game
ncaa_13_14_two_bot['2P'] = ncaa_13_14_2P_bot/ncaa_13_14_bot['G']
ncaa_14_15_two_bot['2P'] = ncaa_14_15_2P_bot/ncaa_14_15_bot['G']
ncaa_15_16_two_bot['2P'] = ncaa_15_16_2P_bot/ncaa_15_16_bot['G']
ncaa_16_17_two_bot['2P'] = ncaa_16_17_2P_bot/ncaa_16_17_bot['G']
ncaa_17_18_two_bot['2P'] = ncaa_17_18_2P_bot/ncaa_17_18_bot['G']

#calc the 2PA per game
ncaa_13_14_two_bot['2PA'] = ncaa_13_14_2P_2PA_bot/ncaa_13_14_bot['G']
ncaa_14_15_two_bot['2PA'] = ncaa_14_15_2P_2PA_bot/ncaa_14_15_bot['G']
ncaa_15_16_two_bot['2PA'] = ncaa_15_16_2P_2PA_bot/ncaa_15_16_bot['G']
ncaa_16_17_two_bot['2PA'] = ncaa_16_17_2P_2PA_bot/ncaa_16_17_bot['G']
ncaa_17_18_two_bot['2PA'] = ncaa_17_18_2P_2PA_bot/ncaa_17_18_bot['G']

#calc the 3P per game
ncaa_13_14_two_bot['3P'] = ncaa_13_14_bot['3P']/ncaa_13_14_bot['G']
ncaa_14_15_two_bot['3P'] = ncaa_14_15_bot['3P']/ncaa_14_15_bot['G']
ncaa_15_16_two_bot['3P'] = ncaa_15_16_bot['3P']/ncaa_15_16_bot['G']
ncaa_16_17_two_bot['3P'] = ncaa_16_17_bot['3P']/ncaa_16_17_bot['G']
ncaa_17_18_two_bot['3P'] = ncaa_17_18_bot['3P']/ncaa_17_18_bot['G']

#calc the 3PA per game
ncaa_13_14_two_bot['3PA'] = ncaa_13_14_bot['3PA']/ncaa_13_14_bot['G']
ncaa_14_15_two_bot['3PA'] = ncaa_14_15_bot['3PA']/ncaa_14_15_bot['G']
ncaa_15_16_two_bot['3PA'] = ncaa_15_16_bot['3PA']/ncaa_15_16_bot['G']
ncaa_16_17_two_bot['3PA'] = ncaa_16_17_bot['3PA']/ncaa_16_17_bot['G']
ncaa_17_18_two_bot['3PA'] = ncaa_17_18_bot['3PA']/ncaa_17_18_bot['G']

#add year to the dataframe
ncaa_13_14_two_bot['Year'] = '2014'
ncaa_14_15_two_bot['Year'] = '2015'
ncaa_15_16_two_bot['Year'] = '2016'
ncaa_16_17_two_bot['Year'] = '2017'
ncaa_17_18_two_bot['Year'] = '2018'

#groupby year and find avg per game stats of top 30 teams
ncaa_13_14_two_bot = ncaa_13_14_two_bot.groupby(['Year'])
ncaa_13_14_two_bot = (ncaa_13_14_two_bot.sum()/30)
ncaa_14_15_two_bot = ncaa_14_15_two_bot.groupby(['Year'])
ncaa_14_15_two_bot = ncaa_14_15_two_bot.sum()/30
ncaa_15_16_two_bot = ncaa_15_16_two_bot.groupby(['Year'])
ncaa_15_16_two_bot = ncaa_15_16_two_bot.sum()/30
ncaa_16_17_two_bot = ncaa_16_17_two_bot.groupby(['Year'])
ncaa_16_17_two_bot = ncaa_16_17_two_bot.sum()/30
ncaa_17_18_two_bot = ncaa_17_18_two_bot.groupby(['Year'])
ncaa_17_18_two_bot = ncaa_17_18_two_bot.sum()/30

# %%
combined_ncaa_2and3tot_bot = pd.merge(ncaa_13_14_two_bot, ncaa_14_15_two_bot, how='outer', on=['Year', '3P', '3PA', '2P', '2PA'])
combined_ncaa_2and3tot_bot = pd.merge(combined_ncaa_2and3tot_bot, ncaa_15_16_two_bot, how='outer', on=['Year', '3P', '3PA', '2P', '2PA'])
combined_ncaa_2and3tot_bot = pd.merge(combined_ncaa_2and3tot_bot, ncaa_16_17_two_bot, how='outer', on=['Year', '3P', '3PA', '2P', '2PA'])
combined_ncaa_2and3tot_bot = pd.merge(combined_ncaa_2and3tot_bot, ncaa_17_18_two_bot, how='outer', on=['Year', '3P', '3PA', '2P', '2PA'])
combined_ncaa_2and3tot_bot
# Out:
#              2P        2PA        3P        3PA
# Year
# 2014  16.783898  36.376893  6.023266  18.255473
# 2015  15.802638  35.769894  5.746480  17.820067
# 2016  17.054780  37.753882  6.165489  19.118230
# 2017  17.123935  37.310441  6.663723  20.167004
# 2018  17.199274  36.740143  6.837467  20.852614

# %%
#ncaa div all 
ncaa_13_14_two_all = pd.DataFrame()
ncaa_14_15_two_all = pd.DataFrame()
ncaa_15_16_two_all = pd.DataFrame()
ncaa_16_17_two_all = pd.DataFrame()
ncaa_17_18_two_all = pd.DataFrame()
#find the amount of 2PA 
ncaa_13_14_2P_2PA_all = ncaa_13_14['FGA'] - ncaa_13_14['3PA']
ncaa_14_15_2P_2PA_all = ncaa_14_15['FGA'] - ncaa_14_15['3PA']
ncaa_15_16_2P_2PA_all = ncaa_15_16['FGA'] - ncaa_15_16['3PA']
ncaa_16_17_2P_2PA_all = ncaa_16_17['FGA'] - ncaa_16_17['3PA']
ncaa_17_18_2P_2PA_all = ncaa_17_18['FGA'] - ncaa_17_18['3PA']

#find the amount of 2P
ncaa_13_14_2P_all = ncaa_13_14['FG'] - ncaa_13_14['3P']
ncaa_14_15_2P_all = ncaa_14_15['FG'] - ncaa_14_15['3P']
ncaa_15_16_2P_all = ncaa_15_16['FG'] - ncaa_15_16['3P']
ncaa_16_17_2P_all = ncaa_16_17['FG'] - ncaa_16_17['3P']
ncaa_17_18_2P_all = ncaa_17_18['FG'] - ncaa_17_18['3P']

#calc the 2P per game
ncaa_13_14_two_all['2P'] = ncaa_13_14_2P_all/ncaa_13_14['G']
ncaa_14_15_two_all['2P'] = ncaa_14_15_2P_all/ncaa_14_15['G']
ncaa_15_16_two_all['2P'] = ncaa_15_16_2P_all/ncaa_15_16['G']
ncaa_16_17_two_all['2P'] = ncaa_16_17_2P_all/ncaa_16_17['G']
ncaa_17_18_two_all['2P'] = ncaa_17_18_2P_all/ncaa_17_18['G']

#calc the 2PA per game
ncaa_13_14_two_all['2PA'] = ncaa_13_14_2P_2PA_all/ncaa_13_14['G']
ncaa_14_15_two_all['2PA'] = ncaa_14_15_2P_2PA_all/ncaa_14_15['G']
ncaa_15_16_two_all['2PA'] = ncaa_15_16_2P_2PA_all/ncaa_15_16['G']
ncaa_16_17_two_all['2PA'] = ncaa_16_17_2P_2PA_all/ncaa_16_17['G']
ncaa_17_18_two_all['2PA'] = ncaa_17_18_2P_2PA_all/ncaa_17_18['G']

#calc the 3P per game
ncaa_13_14_two_all['3P'] = ncaa_13_14['3P']/ncaa_13_14['G']
ncaa_14_15_two_all['3P'] = ncaa_14_15['3P']/ncaa_14_15['G']
ncaa_15_16_two_all['3P'] = ncaa_15_16['3P']/ncaa_15_16['G']
ncaa_16_17_two_all['3P'] = ncaa_16_17['3P']/ncaa_16_17['G']
ncaa_17_18_two_all['3P'] = ncaa_17_18['3P']/ncaa_17_18['G']

#calc the 3PA per game
ncaa_13_14_two_all['3PA'] = ncaa_13_14['3PA']/ncaa_13_14['G']
ncaa_14_15_two_all['3PA'] = ncaa_14_15['3PA']/ncaa_14_15['G']
ncaa_15_16_two_all['3PA'] = ncaa_15_16['3PA']/ncaa_15_16['G']
ncaa_16_17_two_all['3PA'] = ncaa_16_17['3PA']/ncaa_16_17['G']
ncaa_17_18_two_all['3PA'] = ncaa_17_18['3PA']/ncaa_17_18['G']

#add year to the dataframe
ncaa_13_14_two_all['Year'] = '2014'
ncaa_14_15_two_all['Year'] = '2015'
ncaa_15_16_two_all['Year'] = '2016'
ncaa_16_17_two_all['Year'] = '2017'
ncaa_17_18_two_all['Year'] = '2018'

#groupby year and find avg per game stats of all teams
ncaa_13_14_two_all = ncaa_13_14_two_all.groupby(['Year'])
ncaa_13_14_two_all = (ncaa_13_14_two_all.sum()/ncaa_13_14_two_all.count())
ncaa_14_15_two_all = ncaa_14_15_two_all.groupby(['Year'])
ncaa_14_15_two_all = ncaa_14_15_two_all.sum()/ncaa_14_15_two_all.count()
ncaa_15_16_two_all = ncaa_15_16_two_all.groupby(['Year'])
ncaa_15_16_two_all = ncaa_15_16_two_all.sum()/ncaa_15_16_two_all.count()
ncaa_16_17_two_all = ncaa_16_17_two_all.groupby(['Year'])
ncaa_16_17_two_all = ncaa_16_17_two_all.sum()/ncaa_16_17_two_all.count()
ncaa_17_18_two_all = ncaa_17_18_two_all.groupby(['Year'])
ncaa_17_18_two_all = ncaa_17_18_two_all.sum()/ncaa_17_18_two_all.count()

# %%
combined_ncaa_2and3tot_all = pd.merge(ncaa_13_14_two_all, ncaa_14_15_two_all, how='outer', on=['Year', '3P', '3PA', '2P', '2PA'])
combined_ncaa_2and3tot_all = pd.merge(combined_ncaa_2and3tot_all, ncaa_15_16_two_all, how='outer', on=['Year', '3P', '3PA', '2P', '2PA'])
combined_ncaa_2and3tot_all = pd.merge(combined_ncaa_2and3tot_all, ncaa_16_17_two_all, how='outer', on=['Year', '3P', '3PA', '2P', '2PA'])
combined_ncaa_2and3tot_all = pd.merge(combined_ncaa_2and3tot_all, ncaa_17_18_two_all, how='outer', on=['Year', '3P', '3PA', '2P', '2PA'])
combined_ncaa_2and3tot_all
# Out:
#              2P        2PA        3P        3PA
# Year
# 2014  18.164612  37.152041  6.302776  18.228471
# 2015  17.177578  35.726903  6.400627  18.575993
# 2016  18.356929  37.438970  7.106534  20.477794
# 2017  18.288412  36.846901  7.420760  21.113553
# 2018  18.351471  36.461522  7.678220  21.832399

# %% [markdown]
# # Visualizations

# %%
plt.figure(figsize=(12,9))
plt.errorbar(combined_ncaa_2and3tot.index, combined_ncaa_2and3tot['3PA'],
             marker='o', linestyle='--', label='3PA Top 30 Avg', color='green')
plt.errorbar(combined_ncaa_2and3tot_all.index, combined_ncaa_2and3tot_all['3PA'],
             marker='v', linestyle='--', label='3PA All Avg')
plt.errorbar(combined_ncaa_2and3tot_bot.index, combined_ncaa_2and3tot_bot['3PA'],
             marker='p', linestyle='--', label='3PA Bot 30 Avg', color='red')

plt.grid()
plt.legend(loc='best', fancybox=True)
plt.title("3PT Shots Over the Years (NCAA Div 1)")
plt.xlabel("Year")
plt.ylabel("3PT Shots Attempted (per game)")
plt.savefig("Charts/3pt_ncaa")
# Save the Figure
plt.show()

# %%
plt.figure(figsize=(12,9))
plt.errorbar(combined_ncaa_2and3tot.index, combined_ncaa_2and3tot['2PA'], 
             marker='o', linestyle='--', label='2PA Top 30', color='green')
plt.errorbar(combined_ncaa_2and3tot_all.index, combined_ncaa_2and3tot_all['2PA'],
             marker='v', linestyle='--', label='2PA All Avg')
plt.errorbar(combined_ncaa_2and3tot_bot.index, combined_ncaa_2and3tot_bot['2PA'],
             marker='p', linestyle='--', label='2PA Bot 30', color='red')

plt.grid()
plt.legend(loc='best', fancybox=True)
plt.title("2PT Shots Over the Years (NCAA Div 1)")
plt.xlabel("Year")
plt.ylabel("2PT Shots Attempted (per game)")
plt.savefig("Charts/2pt_ncaa")
# Save the Figure
plt.show()
