# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt
import scipy.stats as stats

nba_17_18 = pd.read_csv("NBA data per game (team)/17-18 NBA team per.csv")
nba_16_17 = pd.read_csv("NBA data per game (team)/16-17 NBA team per.csv")
nba_15_16 = pd.read_csv("NBA data per game (team)/15-16 NBA team per.csv")
nba_14_15 = pd.read_csv("NBA data per game (team)/14-15 NBA team per.csv")
nba_13_14 = pd.read_csv("NBA data per game (team)/13-14 NBA team per.csv")

nba_standings_17_18 = pd.read_csv('NBA data (standings)/17-18 NBA standings.csv')
nba_standings_16_17 = pd.read_csv('NBA data (standings)/16-17 NBA standings.csv')
nba_standings_15_16 = pd.read_csv('NBA data (standings)/15-16 NBA standings.csv')
nba_standings_14_15 = pd.read_csv('NBA data (standings)/14-15 NBA standings.csv')
nba_standings_13_14 = pd.read_csv('NBA data (standings)/13-14 NBA standings.csv')

nba_15_16.head()
# Out:
#     Rk                    Team   G     MP    FG   FGA    FG%    3P   3PA  \
# 0  1.0  Golden State Warriors*  82  242.4  42.5  87.3  0.487  13.1  31.6
# 1  2.0  Oklahoma City Thunder*  82  241.8  41.1  86.4  0.476   8.3  23.7
# 2  3.0        Sacramento Kings  82  241.5  40.0  86.4  0.464   8.0  22.4
# 3  4.0        Houston Rockets*  82  241.8  37.7  83.5  0.452  10.7  30.9
# 4  5.0         Boston Celtics*  82  241.2  39.2  89.2  0.439   8.7  26.1
#
#      3P%  ...      FT%   ORB   DRB   TRB   AST   STL  BLK   TOV    PF    PTS
# 0  0.416  ...    0.763  10.0  36.2  46.2  28.9   8.4  6.1  15.2  20.7  114.9
# 1  0.349  ...    0.782  13.1  35.6  48.6  23.0   7.4  5.9  15.9  20.6  110.2
# 2  0.359  ...    0.725  10.6  33.7  44.2  24.5   8.9  4.5  16.2  20.4  106.6
# 3  0.347  ...    0.694  11.3  31.7  43.1  22.2  10.0  5.2  15.9  21.8  106.5
# 4  0.335  ...    0.788  11.6  33.3  44.9  24.2   9.2  4.2  13.7  21.9  105.7
#
# [5 rows x 25 columns]

# %% [markdown]
# # 3P, 3PA, and 3P% Team Comparisons

# %%
three_stats_13_14 = pd.DataFrame(nba_13_14[['Team', '3P', '3PA', '3P%']])
three_stats_13_14.head()
# Out:
#                       Team   3P   3PA    3P%
# 0    Los Angeles Clippers*  8.5  24.0  0.352
# 1         Houston Rockets*  9.5  26.6  0.358
# 2   Minnesota Timberwolves  7.3  21.4  0.341
# 3  Portland Trail Blazers*  9.4  25.3  0.372
# 4   Oklahoma City Thunder*  8.1  22.4  0.361

# %%
three_stats_14_15 = pd.DataFrame(nba_14_15[['Team', '3P', '3PA', '3P%']])

# %%
three_stats_15_16 = pd.DataFrame(nba_15_16[['Team', '3P', '3PA', '3P%']])

# %%
three_stats_16_17 = pd.DataFrame(nba_16_17[['Team', '3P', '3PA', '3P%']])

# %%
three_stats_17_18 = pd.DataFrame(nba_17_18[['Team', '3P', '3PA', '3P%']])

# %%
plt.figure(figsize=(12,9))
three_made = (three_stats_13_14['3P'])

three_attempt = (three_stats_13_14['3PA'])


n=len(three_stats_13_14['Team'])
ind=np.arange(n)
width=0.35


p1=plt.bar(ind, three_made, width, color='#3CC76F')
p2=plt.bar(ind, three_attempt, width, bottom=three_made, color='#DF2424')

plt.ylabel('Three Pointers')
plt.title('From Downtown (2013-2014)')
plt.xticks(ind, (three_stats_13_14['Team']), rotation='vertical')
plt.legend((p1[0], p2[0]), ('3P Made', '3P Attempts'), loc='best')
plt.tick_params(axis='x', pad=5)

plt.show()

# %% [markdown]
# # Standings vs 3P%

# %%
nba_standings_13_14.head()
# Out:
#     Rk                    Team   Age     W     L  PW  PL   MOV   SOS   SRS  \
# 0  1.0      San Antonio Spurs*  28.9  62.0  20.0  61  21  7.72  0.28  8.00
# 1  2.0   Los Angeles Clippers*  28.1  57.0  25.0  59  23  6.98  0.30  7.27
# 2  3.0  Oklahoma City Thunder*  26.2  59.0  23.0  58  24  6.34  0.32  6.66
# 3  4.0  Golden State Warriors*  26.3  51.0  31.0  54  28  4.80  0.34  5.15
# 4  5.0        Houston Rockets*  25.4  54.0  28.0  53  29  4.56  0.50  5.06
#
#      ...      TOV%  ORB%  FT/FGA  eFG%.1  TOV%.1  DRB%  FT/FGA.1  \
# 0    ...      13.5  22.7   0.188   0.482    12.8  76.4     0.184
# 1    ...      12.7  25.0   0.258   0.484    13.8  72.5     0.222
# 2    ...      14.0  26.5   0.244   0.488    13.9  75.6     0.221
# 3    ...      13.8  25.1   0.186   0.477    13.6  76.3     0.224
# 4    ...      14.6  27.4   0.275   0.489    12.5  74.1     0.193
#
#                      Arena  Attend.  Attend./G
# 0              AT&T Center   755031      18415
# ...

# %%
standings_13_14 = pd.DataFrame(nba_standings_13_14[['Team', 'W', 'L']])

# %%
standings_13_14 = standings_13_14.sort_values(by='W', ascending=False)
standings_13_14_combined = standings_13_14.merge(nba_13_14, on='Team')
standings_13_14_combined.head()
# Out:
#                      Team     W     L    Rk   G     MP    FG   FGA    FG%  \
# 0      San Antonio Spurs*  62.0  20.0   6.0  82  240.9  40.6  83.5  0.486
# 1  Oklahoma City Thunder*  59.0  23.0   5.0  82  241.5  39.0  82.7  0.471
# 2   Los Angeles Clippers*  57.0  25.0   1.0  82  240.9  39.1  82.5  0.474
# 3         Indiana Pacers*  56.0  26.0  24.0  82  241.2  36.0  80.2  0.449
# 4        Houston Rockets*  54.0  28.0   2.0  82  241.8  38.0  80.5  0.472
#
#     3P  ...      FT%   ORB   DRB   TRB   AST  STL  BLK   TOV    PF    PTS
# 0  8.5  ...    0.785   9.3  34.0  43.3  25.2  7.4  5.1  14.4  18.2  105.4
# 1  8.1  ...    0.806  10.8  33.9  44.7  21.9  8.3  6.1  15.3  22.7  106.2
# 2  8.5  ...    0.730  10.5  32.5  43.0  24.6  8.6  4.8  13.9  21.5  107.9
# 3  6.7  ...    0.779  10.2  34.5  44.7  20.1  6.7  5.4  15.1  20.4   96.7
# 4  9.5  ...    0.712  11.2  34.1  45.3  21.4  7.6  5.6  16.1  20.4  107.7
#
# [5 rows x 27 columns]

# %%
standings_13_14_top5 = standings_13_14_combined.drop(standings_13_14_combined.index[5:])

# %%
standings_14_15 = pd.DataFrame(nba_standings_14_15[['Team', 'W', 'L']])

# %%
standings_14_15 = standings_14_15.sort_values(by='W', ascending=False)
standings_14_15_combined = standings_14_15.merge(nba_14_15, on='Team')
standings_14_15_top5 = standings_14_15_combined.drop(standings_14_15_combined.index[5:])

# %%
standings_15_16 = pd.DataFrame(nba_standings_15_16[['Team', 'W', 'L']])

# %%
standings_15_16 = standings_15_16.sort_values(by='W', ascending=False)
standings_15_16_combined = standings_15_16.merge(nba_15_16, on='Team')
standings_15_16_top5 = standings_15_16_combined.drop(standings_15_16_combined.index[5:])

# %%
standings_16_17 = pd.DataFrame(nba_standings_16_17[['Team', 'W', 'L']])

# %%
standings_16_17 = standings_16_17.sort_values(by='W', ascending=False)
standings_16_17_combined = standings_16_17.merge(nba_16_17, on='Team')
standings_16_17_top5 = standings_16_17_combined.drop(standings_16_17_combined.index[5:])

# %%
standings_17_18 = pd.DataFrame(nba_standings_17_18[['Team', 'W', 'L']])

# %%
standings_17_18 = standings_17_18.sort_values(by='W', ascending=False)
standings_17_18_combined = standings_17_18.merge(nba_17_18, on='Team')
standings_17_18_top5 = standings_17_18_combined.drop(standings_17_18_combined.index[5:])
standings_17_18_top5
# Out:
#                      Team     W     L    Rk   G     MP    FG   FGA    FG%  \
# 0        Houston Rockets*  65.0  17.0   2.0  82  240.9  38.7  84.2  0.460
# 1        Toronto Raptors*  59.0  23.0   4.0  82  241.8  41.3  87.4  0.472
# 2  Golden State Warriors*  58.0  24.0   1.0  82  240.6  42.8  85.1  0.503
# 3         Boston Celtics*  55.0  27.0  20.0  82  241.5  38.3  85.1  0.450
# 4     Philadelphia 76ers*  52.0  30.0   7.0  82  241.2  40.8  86.6  0.472
#
#      3P  ...      FT%   ORB   DRB   TRB   AST  STL  BLK   TOV    PF    PTS
# 0  15.3  ...    0.781   9.0  34.5  43.5  21.5  8.5  4.8  13.8  19.5  112.4
# 1  11.8  ...    0.794   9.8  34.2  44.0  24.3  7.6  6.1  13.4  21.7  111.7
# 2  11.3  ...    0.815   8.4  35.1  43.5  29.3  8.0  7.5  15.5  19.6  113.5
# 3  11.5  ...    0.771   9.4  35.1  44.5  22.5  7.4  4.5  14.0  19.7  104.0
# 4  11.0  ...    0.752  10.9  36.5  47.4  27.1  8.3  5.1  16.5  22.1  109.8
#
# [5 rows x 27 columns]

# %% [markdown]
# #### Clean Top 5 Data by Categories
# - example being by 3pts, 2pts

# %%
threes_win_13_14 = pd.DataFrame(standings_13_14_top5[['Team', 'W', '3P']])
threes_win_13_14['Year'] = ['2014', '2014', '2014', '2014', '2014']
threes_win_13_14['Rank'] = ['1', '2', '3', '4', '5']

# %%
threes_win_14_15 = pd.DataFrame(standings_14_15_top5[['Team', 'W','3P']])
threes_win_14_15['Year'] = ['2015', '2015', '2015', '2015', '2015']
threes_win_14_15['Rank'] = ['1', '2', '3', '4', '5']

# %%
threes_win_15_16 = pd.DataFrame(standings_15_16_top5[['Team', 'W', '3P']])
threes_win_15_16['Year'] = ['2016', '2016', '2016', '2016', '2016']
threes_win_15_16['Rank'] = ['1', '2', '3', '4', '5']

# %%
threes_win_16_17 = pd.DataFrame(standings_16_17_top5[['Team', 'W', '3P']])
threes_win_16_17['Year'] = ['2017', '2017', '2017', '2017', '2017']
threes_win_16_17['Rank'] = ['1', '2', '3', '4', '5']

# %%
threes_win_17_18 = pd.DataFrame(standings_17_18_top5[['Team', 'W', '3P']])
threes_win_17_18['Year'] = ['2018', '2018', '2018', '2018', '2018']
threes_win_17_18['Rank'] = ['1', '2', '3', '4', '5']
threes_win_17_18
# Out:
#                      Team     W    3P  Year Rank
# 0        Houston Rockets*  65.0  15.3  2018    1
# 1        Toronto Raptors*  59.0  11.8  2018    2
# 2  Golden State Warriors*  58.0  11.3  2018    3
# 3         Boston Celtics*  55.0  11.5  2018    4
# 4     Philadelphia 76ers*  52.0  11.0  2018    5

# %%
threes_win_17_18_x= threes_win_17_18.pivot(index='Rank', columns='Year', values='3P')
threes_win_16_17_x= threes_win_16_17.pivot(index='Rank', columns='Year', values='3P')
threes_win_15_16_x= threes_win_15_16.pivot(index='Rank', columns='Year', values='3P')
threes_win_14_15_x= threes_win_14_15.pivot(index='Rank', columns='Year', values='3P')
threes_win_13_14_x= threes_win_13_14.pivot(index='Rank', columns='Year', values='3P')

# %%
three = pd.merge(threes_win_13_14_x, threes_win_14_15_x, how='outer', on='Rank')
three = pd.merge(three, threes_win_15_16_x, how='outer', on='Rank')
three = pd.merge(three, threes_win_16_17_x, how='outer', on='Rank')
three = pd.merge(three, threes_win_17_18_x, how='outer', on='Rank')

# %%
three
# Out:
# Year  2014  2015  2016  2017  2018
# Rank
# 1      8.5  10.8  13.1  12.0  15.3
# 2      8.1  10.0   7.0   9.2  11.8
# 3      8.5  11.4  10.7  14.4  11.3
# 4      6.7  10.1   8.6  12.0  11.5
# 5      9.5   8.3   8.3  10.3  11.0

# %% [markdown]
# #### Graph 3PT By Years
# * Try to graph by 3PTs made over the year
# * And include wins by graphing by index number

# %%
plt.errorbar(three.index, three['2014'],
             marker='o', linestyle='--', label='2014')
plt.errorbar(three.index, three['2015'], 
             marker='v', linestyle='--', label='2015')
plt.errorbar(three.index, three['2016'], 
             marker='^', linestyle='--', label='2016')
plt.errorbar(three.index, three['2017'],
             marker='s', linestyle='--', label='2017')
plt.errorbar(three.index, three['2018'],
             marker='p', linestyle='--', label='2018')

plt.grid()
plt.legend(loc='best', fancybox=True)
plt.title("Top 5 3PT")
plt.xlabel("Rank")
plt.ylabel("3PT per game")

# Save the Figure
plt.show()

# %% [markdown]
# # 2 PT Top 5 Comp

# %%
twos_win_13_14 = pd.DataFrame(standings_13_14_top5[['Team', 'W', '2P']])
twos_win_14_15 = pd.DataFrame(standings_14_15_top5[['Team', 'W','2P']])
twos_win_15_16 = pd.DataFrame(standings_15_16_top5[['Team', 'W', '2P']])
twos_win_16_17 = pd.DataFrame(standings_16_17_top5[['Team', 'W', '2P']])
twos_win_17_18 = pd.DataFrame(standings_17_18_top5[['Team', 'W', '2P']])

# %%
twos_win_13_14['Year'] = ['2014', '2014', '2014', '2014', '2014']
twos_win_13_14['Rank'] = ['1', '2', '3', '4', '5']
twos_win_14_15['Year'] = ['2015', '2015', '2015', '2015', '2015']
twos_win_14_15['Rank'] = ['1', '2', '3', '4', '5']
twos_win_15_16['Year'] = ['2016', '2016', '2016', '2016', '2016']
twos_win_15_16['Rank'] = ['1', '2', '3', '4', '5']
twos_win_16_17['Year'] = ['2017', '2017', '2017', '2017', '2017']
twos_win_16_17['Rank'] = ['1', '2', '3', '4', '5']
twos_win_17_18['Year'] = ['2018', '2018', '2018', '2018', '2018']
twos_win_17_18['Rank'] = ['1', '2', '3', '4', '5']

# %%
twos_win_17_18_x= twos_win_17_18.pivot(index='Rank', columns='Year', values='2P')
twos_win_16_17_x= twos_win_16_17.pivot(index='Rank', columns='Year', values='2P')
twos_win_15_16_x= twos_win_15_16.pivot(index='Rank', columns='Year', values='2P')
twos_win_14_15_x= twos_win_14_15.pivot(index='Rank', columns='Year', values='2P')
twos_win_13_14_x= twos_win_13_14.pivot(index='Rank', columns='Year', values='2P')

# %%
two = pd.merge(twos_win_13_14_x, twos_win_14_15_x, how='outer', on='Rank')
two = pd.merge(two, twos_win_15_16_x, how='outer', on='Rank')
two = pd.merge(two, twos_win_16_17_x, how='outer', on='Rank')
two = pd.merge(two, twos_win_17_18_x, how='outer', on='Rank')

# %%
two
# Out:
# Year  2014  2015  2016  2017  2018
# Rank
# 1     32.0  30.8  29.4  31.1  23.4
# 2     30.9  28.1  33.2  30.1  29.5
# 3     30.7  25.6  27.9  25.9  31.5
# 4     29.3  29.3  28.0  26.6  26.9
# 5     28.5  30.9  32.9  29.3  29.9

# %%
plt.errorbar(two.index, two['2014'],
             marker='o', linestyle='--', label='2014')
plt.errorbar(two.index, two['2015'], 
             marker='v', linestyle='--', label='2015')
plt.errorbar(two.index, two['2016'], 
             marker='^', linestyle='--', label='2016')
plt.errorbar(two.index, two['2017'],
             marker='s', linestyle='--', label='2017')
plt.errorbar(two.index, two['2018'],
             marker='p', linestyle='--', label='2018')

plt.grid()
plt.legend(loc='best', fancybox=True)
plt.title("Top 5 2PT")
plt.xlabel("Rank")
plt.ylabel("2PT per game")

# Save the Figure
plt.show()

# %% [markdown]
# # League 2PT attempts vs 3PT attempts

# %%
#league average
nba_17_18_x = pd.DataFrame(standings_17_18_combined[['3P', '3PA', '2P', '2PA']]).drop(standings_17_18_combined.index[30])
nba_16_17_x = pd.DataFrame(standings_16_17_combined[['3P', '3PA', '2P', '2PA']]).drop(standings_16_17_combined.index[30])
nba_15_16_x = pd.DataFrame(standings_15_16_combined[['3P', '3PA', '2P', '2PA']]).drop(standings_15_16_combined.index[30])
nba_14_15_x = pd.DataFrame(standings_14_15_combined[['3P', '3PA', '2P', '2PA']]).drop(standings_14_15_combined.index[30])
nba_13_14_x = pd.DataFrame(standings_13_14_combined[['3P', '3PA', '2P', '2PA']]).drop(standings_13_14_combined.index[30])

nba_13_14_x['Year'] = '2014'
nba_14_15_x['Year'] = '2015'
nba_15_16_x['Year'] = '2016'
nba_16_17_x['Year'] = '2017'
nba_17_18_x['Year'] = '2018'

nba_13_14_x = nba_13_14_x.groupby(['Year'])
nba_13_14_x = (nba_13_14_x.sum()/30)
nba_14_15_x = nba_14_15_x.groupby(['Year'])
nba_14_15_x = nba_14_15_x.sum()/30
nba_15_16_x = nba_15_16_x.groupby(['Year'])
nba_15_16_x = nba_15_16_x.sum()/30
nba_16_17_x = nba_16_17_x.groupby(['Year'])
nba_16_17_x = nba_16_17_x.sum()/30
nba_17_18_x = nba_17_18_x.groupby(['Year'])
nba_17_18_x = nba_17_18_x.sum()/30

# %%
combined_2and3tot = pd.merge(nba_13_14_x, nba_14_15_x, how='outer', on=['Year', '3P', '3PA', '2P', '2PA'])
combined_2and3tot = pd.merge(combined_2and3tot, nba_15_16_x, how='outer', on=['Year', '3P', '3PA', '2P', '2PA'])
combined_2and3tot = pd.merge(combined_2and3tot, nba_16_17_x, how='outer', on=['Year', '3P', '3PA', '2P', '2PA'])
combined_2and3tot = pd.merge(combined_2and3tot, nba_17_18_x, how='outer', on=['Year', '3P', '3PA', '2P', '2PA'])
combined_2and3tot
# Out:
#              3P        3PA         2P        2PA
# Year
# 2014   7.743333  21.536667  29.973333  61.463333
# 2015   7.850000  22.410000  29.673333  61.160000
# 2016   8.506667  24.083333  29.720000  60.493333
# 2017   9.650000  27.003333  29.390000  58.410000
# 2018  10.486667  28.996667  29.123333  57.050000

# %%
#Top 5 data 
nba_17_18_x_top5 = pd.DataFrame(standings_17_18_top5[['3P', '3PA', '2P', '2PA']])
nba_16_17_x_top5 = pd.DataFrame(standings_16_17_top5[['3P', '3PA', '2P', '2PA']])
nba_15_16_x_top5 = pd.DataFrame(standings_15_16_top5[['3P', '3PA', '2P', '2PA']])
nba_14_15_x_top5 = pd.DataFrame(standings_14_15_top5[['3P', '3PA', '2P', '2PA']])
nba_13_14_x_top5 = pd.DataFrame(standings_13_14_top5[['3P', '3PA', '2P', '2PA']])

nba_13_14_x_top5['Year'] = '2014'
nba_14_15_x_top5['Year'] = '2015'
nba_15_16_x_top5['Year'] = '2016'
nba_16_17_x_top5['Year'] = '2017'
nba_17_18_x_top5['Year'] = '2018'

nba_13_14_x_top5 = nba_13_14_x_top5.groupby(['Year'])
nba_13_14_x_top5 = (nba_13_14_x_top5.sum()/5)
nba_14_15_x_top5 = nba_14_15_x_top5.groupby(['Year'])
nba_14_15_x_top5 = nba_14_15_x_top5.sum()/5
nba_15_16_x_top5 = nba_15_16_x_top5.groupby(['Year'])
nba_15_16_x_top5 = nba_15_16_x_top5.sum()/5
nba_16_17_x_top5 = nba_16_17_x_top5.groupby(['Year'])
nba_16_17_x_top5 = nba_16_17_x_top5.sum()/5
nba_17_18_x_top5 = nba_17_18_x_top5.groupby(['Year'])
nba_17_18_x_top5 = nba_17_18_x_top5.sum()/5

# %%
combined_2and3tot_top5 = pd.merge(nba_13_14_x_top5, nba_14_15_x_top5, how='outer', on=['Year', '3P', '3PA', '2P', '2PA'])
combined_2and3tot_top5 = pd.merge(combined_2and3tot_top5, nba_15_16_x_top5, how='outer', on=['Year', '3P', '3PA', '2P', '2PA'])
combined_2and3tot_top5 = pd.merge(combined_2and3tot_top5, nba_16_17_x_top5, how='outer', on=['Year', '3P', '3PA', '2P', '2PA'])
combined_2and3tot_top5 = pd.merge(combined_2and3tot_top5, nba_17_18_x_top5, how='outer', on=['Year', '3P', '3PA', '2P', '2PA'])
combined_2and3tot_top5
# Out:
#          3P    3PA     2P    2PA
# Year
# 2014   8.26  22.64  30.28  59.24
# 2015  10.12  27.06  28.94  56.72
# 2016   9.54  25.36  30.28  59.02
# 2017  11.58  31.16  28.60  54.08
# 2018  12.18  32.88  28.24  52.78

# %%
#Bot 5 averages
#drop unwanted rows
standings_17_18_bot5 = standings_17_18_combined.drop(standings_17_18_combined.index[:25]
                                                    ).drop(standings_17_18_combined.index[30])
standings_16_17_bot5 = standings_16_17_combined.drop(standings_16_17_combined.index[:25]
                                                    ).drop(standings_16_17_combined.index[30])
standings_15_16_bot5 = standings_15_16_combined.drop(standings_15_16_combined.index[:25]
                                                    ).drop(standings_15_16_combined.index[30])
standings_14_15_bot5 = standings_14_15_combined.drop(standings_14_15_combined.index[:25]
                                                    ).drop(standings_14_15_combined.index[30])
standings_13_14_bot5 = standings_13_14_combined.drop(standings_13_14_combined.index[:25]
                                                    ).drop(standings_13_14_combined.index[30])
#Pull columns needed
nba_17_18_x_bot5 = pd.DataFrame(standings_17_18_bot5[['3P', '3PA', '2P', '2PA']])
nba_16_17_x_bot5 = pd.DataFrame(standings_16_17_bot5[['3P', '3PA', '2P', '2PA']])
nba_15_16_x_bot5 = pd.DataFrame(standings_15_16_bot5[['3P', '3PA', '2P', '2PA']])
nba_14_15_x_bot5 = pd.DataFrame(standings_14_15_bot5[['3P', '3PA', '2P', '2PA']])
nba_13_14_x_bot5 = pd.DataFrame(standings_13_14_bot5[['3P', '3PA', '2P', '2PA']])
#Add year to correct data
nba_13_14_x_bot5['Year'] = '2014'
nba_14_15_x_bot5['Year'] = '2015'
nba_15_16_x_bot5['Year'] = '2016'
nba_16_17_x_bot5['Year'] = '2017'
nba_17_18_x_bot5['Year'] = '2018'
#calculate the avg
nba_13_14_x_bot5 = nba_13_14_x_bot5.groupby(['Year'])
nba_13_14_x_bot5 = (nba_13_14_x_bot5.sum()/5)
nba_14_15_x_bot5 = nba_14_15_x_bot5.groupby(['Year'])
nba_14_15_x_bot5 = nba_14_15_x_bot5.sum()/5
nba_15_16_x_bot5 = nba_15_16_x_bot5.groupby(['Year'])
nba_15_16_x_bot5 = nba_15_16_x_bot5.sum()/5
nba_16_17_x_bot5 = nba_16_17_x_bot5.groupby(['Year'])
nba_16_17_x_bot5 = nba_16_17_x_bot5.sum()/5
nba_17_18_x_bot5 = nba_17_18_x_bot5.groupby(['Year'])
nba_17_18_x_bot5 = nba_17_18_x_bot5.sum()/5

# %%
combined_2and3tot_bot5 = pd.merge(nba_13_14_x_bot5, nba_14_15_x_bot5, how='outer', on=['Year', '3P', '3PA', '2P', '2PA'])
combined_2and3tot_bot5 = pd.merge(combined_2and3tot_bot5, nba_15_16_x_bot5, how='outer', on=['Year', '3P', '3PA', '2P', '2PA'])
combined_2and3tot_bot5 = pd.merge(combined_2and3tot_bot5, nba_16_17_x_bot5, how='outer', on=['Year', '3P', '3PA', '2P', '2PA'])
combined_2and3tot_bot5 = pd.merge(combined_2and3tot_bot5, nba_17_18_x_bot5, how='outer', on=['Year', '3P', '3PA', '2P', '2PA'])
combined_2and3tot_bot5
# Out:
#          3P    3PA     2P    2PA
# Year
# 2014   6.84  20.24  29.82  63.20
# 2015   6.70  19.86  29.34  63.40
# 2016   7.62  22.54  29.28  61.48
# 2017   9.14  27.16  29.42  59.50
# 2018  10.36  29.44  27.70  55.96

# %% [markdown]
# # Visualizations

# %%
plt.figure(figsize=(12,9))
plt.errorbar(combined_2and3tot_top5.index, combined_2and3tot_top5['3PA'],
             marker='p', linestyle='--', label='3PA Top 5', color='green')
plt.errorbar(combined_2and3tot.index, combined_2and3tot['3PA'],
             marker='o', linestyle='--', label='3PA League Avg')
plt.errorbar(combined_2and3tot_bot5.index, combined_2and3tot_bot5['3PA'],
             marker='v', linestyle='--', label='3PA Bot 5', color='red')

plt.grid()
plt.legend(loc='best', fancybox=True)
plt.title("3PT Shots Over the Years (NBA)")
plt.xlabel("Year")
plt.ylabel("3PT Shots Attempted (per game)")
plt.savefig("Charts/3pt_nba")
# Save the Figure
plt.show()

# %%
plt.figure(figsize=(12,9))
plt.errorbar(combined_2and3tot_top5.index, combined_2and3tot_top5['2PA'],
             marker='p', linestyle='--', label='2PA Top 5', color='green')
plt.errorbar(combined_2and3tot.index, combined_2and3tot['2PA'],
             marker='o', linestyle='--', label='2PA League Avg')
plt.errorbar(combined_2and3tot_bot5.index, combined_2and3tot_bot5['2PA'],
             marker='v', linestyle='--', label='2PA Bot 5', color='red')
plt.grid()
plt.legend(loc='best', fancybox=True)
plt.title("2PT Shots Over the Years (NBA)")
plt.xlabel("Year")
plt.ylabel("2PT Shots Attempted (per game)")
plt.savefig("Charts/2pt_nba")
# Save the Figure
plt.show()
