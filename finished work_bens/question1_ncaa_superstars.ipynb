# %%
import pandas as pd
import numpy as np

# %%
#get df from csv
ncaa_df = pd.read_csv('NCAA data/cleaned_ncaa_data.csv')
ncaa_group = ncaa_df.groupby(['game_id','season','team_alias','full_name']).mean()
ncaa_df.head()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-3-5d99e1d3c886> in <module>
#       1 #get df from csv
# ----> 2 ncaa_df = pd.read_csv('NCAA data/cleaned_ncaa_data.csv')
#       3 ncaa_group = ncaa_df.groupby(['game_id','season','team_alias','full_name']).mean()
#       4 ncaa_df.head()
#
# ~\Anaconda3\envs\PythonData1\lib\site-packages\pandas\io\parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, escapechar, comment, encoding, dialect, tupleize_cols, error_bad_lines, warn_bad_lines, skipfooter, doublequote, delim_whitespace, low_memory, memory_map, float_precision)
#     676                     skip_blank_lines=skip_blank_lines)
#     677
# --> 678         return _read(filepath_or_buffer, kwds)
#     679
#     680     parser_f.__name__ = name
#
# ~\Anaconda3\envs\PythonData1\lib\site-packages\pandas\io\parsers.py in _read(filepath_or_buffer, kwds)
#     438
#     439     # Create the parser.
# --> 440     parser = TextFileReader(filepath_or_buffer, **kwds)
#     441
#     442     if chunksize or iterator:
#
# ~\Anaconda3\envs\PythonData1\lib\site-packages\pandas\io\parsers.py in __init__(self, f, engine, **kwds)
#     785             self.options['has_index_names'] = kwds['has_index_names']
#     786
# --> 787         self._make_engine(self.engine)
#     788
#     789     def close(self):
#
# ~\Anaconda3\envs\PythonData1\lib\site-packages\pandas\io\parsers.py in _make_engine(self, engine)
#    1012     def _make_engine(self, engine='c'):
#    1013         if engine == 'c':
# -> 1014             self._engine = CParserWrapper(self.f, **self.options)
#    1015         else:
#    1016             if engine == 'python':
#
# ~\Anaconda3\envs\PythonData1\lib\site-packages\pandas\io\parsers.py in __init__(self, src, **kwds)
#    1706         kwds['usecols'] = self.usecols
#    1707
# -> 1708         self._reader = parsers.TextReader(src, **kwds)
#    1709
#    1710         passed_names = self.names is None
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader.__cinit__()
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader._setup_parser_source()
#
# FileNotFoundError: File b'NCAA data/cleaned_ncaa_data.csv' does not exist

# %%
#unneccesary simplification of game_id name with dict
game_id_unique = ncaa_df['game_id'].unique()
game_id_replace = np.arange(0, len(game_id_unique), 1)
game_id_dict = dict(zip(game_id_unique, game_id_replace))
ncaa_df['game_id'] = ncaa_df.game_id.map(game_id_dict)
ncaa_df.head(10)

# %%
#remove games that don't have data for both teams
game_group = ncaa_df.groupby('game_id').nunique()
drop = game_group.loc[omg.team_alias < 2, 'game_id'].index.values
dropped = ncaa_df.set_index('game_id').drop(labels=drop, axis = 0)
dropped = dropped.reset_index()

# %%
#unneccesary simplification of game_id name with dict
game_id_unique = dropped['game_id'].unique()
game_id_replace = np.arange(0, len(game_id_unique), 1)
game_id_dict = dict(zip(game_id_unique, game_id_replace))
dropped['game_id'] = dropped.game_id.map(game_id_dict)
dropped.head()

# %%
#summed groupby season, game_id, and team_alias
game_team_group_sum = dropped.groupby(['season','game_id','team_alias']).sum()
game_team_group_sum.head()

# %%
#get df with team_game_score
game_team_group_sum[['team_game_score']] = game_team_group_sum[['points']]
game_team_group_points_sum = game_team_group_sum[['team_game_score', 'assists']]
game_team_group_points_sum = game_team_group_points_sum.reset_index()
game_team_group_points_sum.head(10)

# %% [markdown]
# # use ncaa_merged as DataFrame for individual stats

# %%
#leftmerge df's by game_id and team_alias
ncaa_merged = dropped.merge(game_team_group_points_sum, on = ['season','game_id', 'team_alias'], how = 'left')
ncaa_merged.head(10)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-eee28b60dba8> in <module>
#       1 #leftmerge df's by game_id and team_alias
# ----> 2 ncaa_merged = dropped.merge(game_team_group_points_sum, on = ['season','game_id', 'team_alias'], how = 'left')
#       3 ncaa_merged.head(10)
#
# NameError: name 'dropped' is not defined

# %% [markdown]
# # use ncaa_contribution for player_contribution

# %%
#get 'player_contribution' column
ncaa_merged['player_contribution (%)'] = ncaa_merged['points']/ncaa_merged['team_game_score']*100
ncaa_contribution = ncaa_merged[['game_id', 'season', 'team_alias','full_name', 'player_contribution (%)']]
ncaa_contribution.head(25)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-ab54b927d7f7> in <module>
#       1 #get 'player_contribution' column
# ----> 2 ncaa_merged['player_contribution (%)'] = ncaa_merged['points']/ncaa_merged['team_game_score']*100
#       3 ncaa_contribution = ncaa_merged[['game_id', 'season', 'team_alias','full_name', 'player_contribution (%)']]
#       4 ncaa_contribution.head(25)
#
# NameError: name 'ncaa_merged' is not defined

# %%
# star_power = top player contribution / avg(next top4)
#iterate through "team_alias" and append name if name changes
team_names = []
game_count = 0
for row in range(len(ncaa_contribution['team_alias'])):
    if row >0:
        if ncaa_contribution.iloc[row, 2] != ncaa_contribution.iloc[row-1, 2] or ncaa_contribution.iloc[row, 0] != ncaa_contribution.iloc[row-1, 0]:
            team_names.append(ncaa_contribution.iloc[row-1, 2])
len(team_names)
# Out:
# 47969

# %%
team_names.append('SUU')

# %%
#for each team grab top 5 contributors
game_number = 0
counter = 0
star_power = []
for team in team_names:
    try:
        top_five = ncaa_contribution.loc[(ncaa_contribution.game_id ==game_number) & (ncaa_contribution.team_alias ==team)].nlargest(5, 'player_contribution (%)')
        top_list = top_five['player_contribution (%)'].tolist()
        star_power.append(top_list[0]/(np.mean(top_list[1:5])))
        counter += 1
        if counter == 2 :
            game_number += 1
            counter = 0
    except IndexError:
        print('indexerror')
print(star_power)
# Out:
# [2.702702702702702, 1.5652173913043477, 1.3333333333333333, 1.7647058823529411, 1.4166666666666667, 2.5641025641025643, 1.6603773584905666, 1.696969696969697, 2.6, 2.0, 2.333333333333333, 1.8181818181818181, 3.2631578947368416, 1.6190476190476195, 2.888888888888889, 5.4399999999999995, 1.3714285714285714, 1.795918367346939, 2.2962962962962963, 1.8245614035087718, 2.4, 3.4444444444444446, 1.3043478260869565, 2.4615384615384617, 2.5142857142857142, 2.4615384615384617, 1.2972972972972974, 1.8095238095238098, 1.4634146341463414, 3.5, 1.3061224489795917, 2.1904761904761902, 1.9090909090909092, 2.5945945945945947, 1.3114754098360655, 2.0000000000000004, 1.2727272727272725, 1.6, 1.9459459459459463, 1.446808510638298, 1.8000000000000003, 1.3333333333333335, 1.6521739130434783, 2.0, 2.0869565217391304, 2.6, 1.6428571428571426, 2.604651162790698, 2.0, 1.9428571428571426, 1.4634146341463414, 1.2972972972972974, 2.188679245283019, 1.7777777777777777, 1.8, 1.6, 1.5609756097560974, 1.888888888888889, 1.5609756097560974, 1.6842105263157894, 2.0740740740740744, 1.7647058823529411, 2.8965517241379315, 3.225806451612903, 1.8947368421052633, 1.2244897959183676, 1.5384615384615388, 2.1818181818181817, 2.666666666666667, 1.568627450980392, 1.7254901960784312, 2.0444444444444443, 1.6470588235294117, 1.7142857142857144, 1.8181818181818181, 2.823529411764706, 1.5555555555555554, 1.909090909090909, 1.6170212765957446, 1.4054054054054053, 2.4615384615384617, 1.92, 1.3076923076923077, 1.3333333333333333, 2.900000000000001, 2.5, 1.5510204081632653, 2.7317073170731705, 2.818181818181818, 1.4166666666666667, 2.3999999999999995, 1.5094339622641508, 1.5609756097560974, 2.0, 2.1333333333333333, 1.2972972972972974, 3.0526315789473686, 3.733333333333333, 1.5999999999999999, 1.7333333333333332, 2.0, 1.72972972972973, 2.0000000000000004, 4.640000000000001, 2.142857142857143, 1.7499999999999998, 1.411764705882353, 1.5555555555555556, 1.7142857142857142, 1.9999999999999998, 2.5806451612903225, 1.2903225806451615, 1.5789473684210527, 2.75, 1.7959183673469385, 1.9534883720930232, 2.358974358974359, 4.689655172413793, 1.4166666666666667, 2.1428571428571423, 2.048780487804878, 2.1818181818181817, 3.2222222222222223, 2.0, 1.5999999999999999, 3.5, 2.13953488372093, 2.2325581395348837, 2.666666666666667, 1.7560975609756098, 1.8536585365853657, 1.833333333333333, 1.9999999999999996, 1.52, 1.8666666666666667, 1.5757575757575757, 2.344827586206897, 2.5454545454545454, 2.0952380952380953, 1.9574468085106385, 1.2244897959183674, 1.714285714285714, 1.8888888888888888, 1.6666666666666667, 1.795918367346939, 3.851851851851852, 1.6888888888888889, 2.2727272727272725, 2.9230769230769225, 1.3636363636363635, 1.5135135135135136, 3.0000000000000004, 1.1111111111111112, 1.8399999999999996, 1.8333333333333333, 1.6744186046511627, 1.5609756097560976, 1.4468085106382977, 1.3953488372093024, 2.074074074074074, 1.4399999999999997, 2.4615384615384612, 1.5384615384615385, 2.2105263157894743, 1.84, 1.3846153846153844, 1.4666666666666666, 2.206896551724138, 2.0, 1.509433962264151, 1.826086956521739, 2.5, 1.276595744680851, 1.4054054054054053, 1.8260869565217388, 1.9166666666666663, 2.181818181818181, 1.5609756097560974, 2.1538461538461537, 1.7358490566037734, 2.4, 2.1999999999999997, 1.6410256410256407, 1.4782608695652177, 1.5714285714285714, 2.727272727272727, 3.0666666666666664, 2.212765957446808, 2.6285714285714286, 1.4399999999999997, 2.8108108108108105, 2.06060606060606, 1.6842105263157894, 1.9591836734693877, 2.2641509433962264, 2.0, 1.4000000000000001, 1.2307692307692308, 1.6326530612244896, 1.866666666666667, 1.5999999999999999, 1.7435897435897436, 2.418604651162791, 3.4117647058823533, 1.3333333333333335, 1.6363636363636362, 2.4390243902439024, 1.846153846153846, 1.1818181818181819, 3.833333333333334, 1.8947368421052633, 1.6666666666666665, 1.4035087719298247, 1.3548387096774193, 1.473684210526316, 2.0689655172413794, 1.8, 1.8, 1.435897435897436, 2.057142857142857, 1.442622950819672, 1 ...

# %%
#get 'assists/score' column
game_team_group_points_sum['assists/score'] = game_team_group_points_sum['assists']/game_team_group_points_sum['team_game_score']
team_df =  game_team_group_points_sum.drop('assists', 1)
team_df.head(10)
# Out:
#    season  game_id team_alias  team_game_score  assists/score
# 0    2013        0        LOU             66.0       0.212121
# 1    2013        0        MEM             72.0       0.236111
# 2    2013        1        ARK             61.0       0.180328
# 3    2013        1        UGA             66.0       0.106061
# 4    2013        2        HOU             78.0       0.217949
# 5    2013        2        USF             69.0       0.188406
# 6    2013        3        FSU             85.0       0.176471
# 7    2013        3        VCU             67.0       0.104478
# 8    2013        4        ASU             76.0       0.236842
# 9    2013        4       STAN             64.0       0.062500

# %%
#add star_power stat to team_df
team_df['star_power'] = np.round(star_power,2)
team_df.head(10)
# Out:
#    season  game_id team_alias  team_game_score  assists/score  differences  \
# 0    2013        0        LOU             66.0       0.212121          NaN
# 1    2013        0        MEM             72.0       0.236111          6.0
# 2    2013        1        ARK             61.0       0.180328        -11.0
# 3    2013        1        UGA             66.0       0.106061          5.0
# 4    2013        2        HOU             78.0       0.217949         12.0
# 5    2013        2        USF             69.0       0.188406         -9.0
# 6    2013        3        FSU             85.0       0.176471         16.0
# 7    2013        3        VCU             67.0       0.104478        -18.0
# 8    2013        4        ASU             76.0       0.236842          9.0
# 9    2013        4       STAN             64.0       0.062500        -12.0
#
#    w/l_ratio  star_power
# 0          0        2.70
# 1          0        1.57
# 2          0        1.33
# 3          0        1.76
# 4          0        1.42
# 5          0        2.56
# 6          0        1.66
# 7          0        1.70
# 8          0        2.60
# 9          0        2.00

# %%
#get team_game_score differences to calculate w/l ratio
team_df['differences'] = team_df['team_game_score'].diff()
team_df.head()
# Out:
#    season  game_id team_alias  team_game_score  assists/score  differences  \
# 0    2013        0        LOU             66.0       0.212121          NaN
# 1    2013        0        MEM             72.0       0.236111          6.0
# 2    2013        1        ARK             61.0       0.180328        -11.0
# 3    2013        1        UGA             66.0       0.106061          5.0
# 4    2013        2        HOU             78.0       0.217949         12.0
#
#    w/l_ratio  star_power
# 0          0        2.70
# 1          0        1.57
# 2          0        1.33
# 3          0        1.76
# 4          0        1.42

# %%
# only grab second team for each game
differences = team_df.iloc[1::2, :]
differences = differences[['differences']]
differences.head()
# Out:
#    differences
# 1          6.0
# 3          5.0
# 5         -9.0
# 7        -18.0
# 9        -12.0

# %%
#do a join of isolated differences
test_df = team_df.join(differences, how='outer', lsuffix = 'trash',rsuffix = '')
test_df.head(10)
# Out:
#    season  game_id team_alias  team_game_score  assists/score  \
# 0    2013        0        LOU             66.0       0.212121
# 1    2013        0        MEM             72.0       0.236111
# 2    2013        1        ARK             61.0       0.180328
# 3    2013        1        UGA             66.0       0.106061
# 4    2013        2        HOU             78.0       0.217949
# 5    2013        2        USF             69.0       0.188406
# 6    2013        3        FSU             85.0       0.176471
# 7    2013        3        VCU             67.0       0.104478
# 8    2013        4        ASU             76.0       0.236842
# 9    2013        4       STAN             64.0       0.062500
#
#    differencestrash  w/l_ratio  star_power  differences
# 0               NaN          0        2.70          NaN
# 1               6.0          0        1.57          6.0
# 2             -11.0          0        1.33          NaN
# 3               5.0          0        1.76          5.0
# 4              12.0          0        1.42          NaN
# 5              -9.0          0        2.56         -9.0
# 6              16.0          0        1.66          NaN
# 7             -18.0          0        1.70        -18.0
# 8               9.0          0        2.60          NaN
# 9             -12.0          0        2.00        -12.0

# %%
#calculate w/l ratio
team_df['w/l_ratio'] = 0
test_df.loc[test_df.differences > 0, 'w/l_ratio'] = 1
test_df.head(10)
# Out:
#    season  game_id team_alias  team_game_score  assists/score  \
# 0    2013        0        LOU             66.0       0.212121
# 1    2013        0        MEM             72.0       0.236111
# 2    2013        1        ARK             61.0       0.180328
# 3    2013        1        UGA             66.0       0.106061
# 4    2013        2        HOU             78.0       0.217949
# 5    2013        2        USF             69.0       0.188406
# 6    2013        3        FSU             85.0       0.176471
# 7    2013        3        VCU             67.0       0.104478
# 8    2013        4        ASU             76.0       0.236842
# 9    2013        4       STAN             64.0       0.062500
#
#    differencestrash  w/l_ratio  star_power  differences
# 0               NaN          0        2.70          NaN
# 1               6.0          1        1.57          6.0
# 2             -11.0          0        1.33          NaN
# 3               5.0          1        1.76          5.0
# 4              12.0          0        1.42          NaN
# 5              -9.0          0        2.56         -9.0
# 6              16.0          0        1.66          NaN
# 7             -18.0          0        1.70        -18.0
# 8               9.0          0        2.60          NaN
# 9             -12.0          0        2.00        -12.0

# %% [markdown]
# # use this for team stats by individual game

# %%
#shift up values of differences column by one to run w/l ratio calcs for other team
test_df.loc[:, 'differences'] = test_df.loc[:, 'differences'].shift(-1)
test_df.loc[test_df.differences < 0, 'w/l_ratio'] = 1
test_df.head(20)
# Out:
#     season  game_id team_alias  team_game_score  assists/score  \
# 0     2013        0        LOU             66.0       0.212121
# 1     2013        0        MEM             72.0       0.236111
# 2     2013        1        ARK             61.0       0.180328
# 3     2013        1        UGA             66.0       0.106061
# 4     2013        2        HOU             78.0       0.217949
# 5     2013        2        USF             69.0       0.188406
# 6     2013        3        FSU             85.0       0.176471
# 7     2013        3        VCU             67.0       0.104478
# 8     2013        4        ASU             76.0       0.236842
# 9     2013        4       STAN             64.0       0.062500
# 10    2013        5       DUKE             66.0       0.287879
# 11    2013        5         VT             48.0       0.166667
# 12    2013        6       RUTG             79.0       0.164557
# 13    2013        6        USF             69.0       0.173913
# 14    2013        7       COLO             68.0       0.132353
# 15    2013        7        WSU             63.0       0.238095
# 16    2013        8        KSU             60.0       0.100000
# 17    2013        8         KU             86.0       0.232558
# 18    2013        9         LT            102.0       0.127451
# 19    2013        9       OKLA             98.0       0.132653
#
#     differencestrash  w/l_ratio  star_power  differences
# 0                NaN          0        2.70          6.0
# 1                6.0          1        1.57          NaN
# 2              -11.0          0        1.33          5.0
# 3                5.0          1        1.76          NaN
# 4               12.0          1        1.42         -9.0
# 5               -9.0          0        2.56          NaN
# 6               16.0          1        1.66        -18.0
# 7              -18.0          0        1.70          NaN
# 8                9.0          1        2.60        -12.0
# 9              -12.0          0        2.00          NaN
# 10               2.0          1        2.33        -18.0
# 11             -18.0          0        1.82          NaN
# 12              31.0          1        3.26        -10.0
# 13             -10.0          0        1.62          NaN
# 14              -1.0          1        2.89         -5.0
# 15              -5.0          0        5.44          NaN
# 16              -3.0          0        1.37         26.0
# 17              26.0          1        1.80          NaN
# 18              16.0          1        2.30         -4.0
# 19              -4.0          0        1.82          NaN

# %%
with_wins = test_df[['season','game_id','team_alias','team_game_score', 'w/l_ratio']]
with_wins.loc[with_wins['w/l_ratio'] == 0, 'w/l_ratio'] = 'L'
with_wins.loc[with_wins['w/l_ratio'] == 1, 'w/l_ratio'] = 'W'
with_wins.head()
# Out:
#    season  game_id team_alias  team_game_score w/l_ratio
# 0    2013        0        LOU             66.0         L
# 1    2013        0        MEM             72.0         W
# 2    2013        1        ARK             61.0         L
# 3    2013        1        UGA             66.0         W
# 4    2013        2        HOU             78.0         W

# %%
win_count = test_df.groupby(['season','team_alias']).sum()
win_count.head()
# Out:
#                    game_id  team_game_score  assists/score  differencestrash  \
# season team_alias
# 2013   AAMU           1409             52.0       0.134615             -12.0
#        AC             5339            214.0       0.723243             -78.0
#        AFA            4818            226.0       0.825461             -36.0
#        AKR            4234            247.0       0.609451             -29.0
#        ALA           36637           2068.0       4.976160            -130.0
#
#                    w/l_ratio  star_power  differences
# season team_alias
# 2013   AAMU                0        3.09         36.0
#        AC                  0        7.08        120.0
#        AFA                 0        9.71         78.0
#        AKR                 1        7.34         54.0
#        ALA                12       71.32         17.0

# %%
win_count = win_count.reset_index()

# %%
win_count['win_count'] = win_count['w/l_ratio']
win_count = win_count[['season','team_alias','win_count']]
win_count.head()
# Out:
#    season team_alias  win_count
# 0    2013       AAMU          0
# 1    2013         AC          0
# 2    2013        AFA          0
# 3    2013        AKR          1
# 4    2013        ALA         12

# %%
#make a table of mean team_performance by season and team
team_performance = test_df.groupby(['season','team_alias']).mean()
team_performance=team_performance.reset_index()
team_performance = team_performance.merge(win_count, on=['season','team_alias'],how = 'outer')
team_performance.head()
# Out:
#    season team_alias     game_id  team_game_score  assists/score  \
# 0    2013       AAMU  1409.00000        52.000000       0.134615
# 1    2013         AC  1334.75000        53.500000       0.180811
# 2    2013        AFA  1204.50000        56.500000       0.206365
# 3    2013        AKR  1058.50000        61.750000       0.152363
# 4    2013        ALA  1181.83871        66.709677       0.160521
#
#    differencestrash  w/l_ratio  star_power  differences  win_count
# 0        -12.000000   0.000000    3.090000    36.000000          0
# 1        -19.500000   0.000000    1.770000    30.000000          0
# 2         -9.000000   0.000000    2.427500    19.500000          0
# 3         -7.250000   0.250000    1.835000    13.500000          1
# 4         -4.193548   0.387097    2.300645     0.548387         12

# %%
game_count = test_df.groupby(['season','team_alias']).count()
game_count['game_count'] = game_count['game_id']
game_count = game_count[game_count['game_count'] > 25]
game_count = game_count[['game_count']]
game_count.head()
# Out:
#                    game_count
# season team_alias
# 2013   ALA                 31
#        ARIZ                38
#        ARK                 34
#        ASU                 33
#        AUB                 30

# %%
game_count = game_count.reset_index()

# %%
final_df = team_performance.merge(game_count, on = ['season','team_alias'], how = 'outer').dropna()
final_df.to_csv('scatter_ncaa.csv')

# %%
team_performance = team_performance.groupby(['season','team_alias']).mean()
team_performance = team_performance[['win_count','w/l_ratio','star_power','assists/score','team_game_score']]
team_performance = team_performance.sort_values(['win_count', 'w/l_ratio','star_power'], ascending = False)
team_performance.head()
# Out:
#                    win_count  w/l_ratio  star_power  assists/score  \
# season team_alias
# 2014   UK                 38   0.974359    1.689487       0.188495
# 2016   GONZ               37   0.948718    1.716667       0.182631
# 2013   FLA                36   0.923077    1.987436       0.184149
# 2014   WIS                36   0.900000    1.937250       0.174833
# 2017   VILL               36   0.900000    1.800250       0.186407
#
#                    team_game_score
# season team_alias
# 2014   UK                74.358974
# 2016   GONZ              82.615385
# 2013   FLA               69.923077
# 2014   WIS               72.500000
# 2017   VILL              86.575000

# %%
team_performance=team_performance.reset_index()

# %%
#how to search results by year
top_ten_by_season = team_performance.loc[team_performance.season == 2013].nlargest(10, 'win_count').groupby('season').mean()
top_ten_by_season.head()
# Out:
#         win_count  w/l_ratio  star_power  assists/score  team_game_score
# season
# 2013         31.3   0.834215    1.904971       0.186158        73.823413

# %% [markdown]
# # avg team_performance by year of top 10 teams

# %%
#avg team_performance by year for top 10 teams
season_avg = []
for season in team_performance['season'].unique():
    season_avg.append(team_performance.loc[team_performance.season == season].nlargest(34, 'win_count'))
#concat and sort
top_ten_per_season = pd.concat(season_avg)
top_ten_per_season.head()
# Out:
#      season team_alias      game_id  team_game_score  assists/score  \
# 87     2013        FLA  1160.000000        69.923077       0.184149
# 330    2013       WICH   874.057143        74.657143       0.183337
# 11     2013       ARIZ  1012.447368        72.868421       0.205605
# 51     2013       CONN  1065.200000        71.825000       0.168568
# 145    2013        LOU  1074.405405        81.027027       0.189206
#
#      differencestrash  w/l_ratio  star_power  differences  win_count
# 87          -1.641026   0.923077    1.987436   -14.466667         36
# 330         13.800000   0.971429    1.979143   -17.000000         34
# 11           5.815789   0.868421    1.689211   -14.315789         33
# 51           4.325000   0.800000    2.144500    -9.200000         32
# 145         15.555556   0.837838    1.941622   -18.478261         31

# %%
top_ten_per_season.to_csv('top_ten_pct_ncaa.csv')

# %%
top_ten_by_season = top_ten_by_season.reset_index()
top_ten_sem = top_ten_sem.reset_index()

# %%
top_ten_by_season =top_ten_by_season.merge(top_ten_sem, on='season', suffixes = ('_mean', '_sem'))

# %%
#pivot
top_ten_by_season['stat']=str('star_power')
top_ten_star_power = top_ten_by_season.pivot(index = 'stat',columns = 'season',values = 'star_power_mean')
top_ten_by_season['stat']=str('assists/score')
top_ten_assists_score = top_ten_by_season.pivot(index = 'stat',columns = 'season',values = 'assists/score_mean')
top_ten_by_season['stat']=str('star_power_sem')
top_ten_star_sem = top_ten_by_season.pivot(index = 'stat',columns = 'season',values = 'star_power_sem')
top_ten_by_season['stat']=str('assists/score_sem')
top_ten_assists_sem = top_ten_by_season.pivot(index = 'stat',columns = 'season',values = 'assists/score_sem')
top_ten_pivot = pd.concat([top_ten_star_power, top_ten_assists_score,top_ten_star_sem,top_ten_assists_sem])
top_ten_pivot
# Out:
# season                 2013      2014      2015      2016      2017
# stat
# star_power         1.904971  1.797953  1.925370  1.871518  1.920190
# assists/score      0.186158  0.190408  0.202837  0.198761  0.201953
# star_power_sem     0.055659  0.035086  0.083516  0.046258  0.060888
# assists/score_sem  0.006508  0.003210  0.007889  0.006552  0.004924

# %%
top_ten_pivot.to_csv('ncaa_top_ten_avg_by_season.csv')
